# %% [markdown]
# <a href="https://colab.research.google.com/github/xrunda/metazoon_nft/blob/main/Whisper_Youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Youtube Videos Transcription with OpenAI's Whisper**
#
# [![blog post shield](https://img.shields.io/static/v1?label=&message=Blog%20post&color=blue&style=for-the-badge&logo=openai&link=https://openai.com/blog/whisper)](https://openai.com/blog/whisper)
# [![notebook shield](https://img.shields.io/static/v1?label=&message=Notebook&color=blue&style=for-the-badge&logo=googlecolab&link=https://colab.research.google.com/github/ArthurFDLR/whisper-youtube/blob/main/whisper_youtube.ipynb)](https://colab.research.google.com/github/ArthurFDLR/whisper-youtube/blob/main/whisper_youtube.ipynb)
# [![repository shield](https://img.shields.io/static/v1?label=&message=Repository&color=blue&style=for-the-badge&logo=github&link=https://github.com/openai/whisper)](https://github.com/openai/whisper)
# [![paper shield](https://img.shields.io/static/v1?label=&message=Paper&color=blue&style=for-the-badge&link=https://cdn.openai.com/papers/whisper.pdf)](https://cdn.openai.com/papers/whisper.pdf)
# [![model card shield](https://img.shields.io/static/v1?label=&message=Model%20card&color=blue&style=for-the-badge&link=https://github.com/openai/whisper/blob/main/model-card.md)](https://github.com/openai/whisper/blob/main/model-card.md)
#
# Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification.
#
# This Notebook will guide you through the transcription of a Youtube video using Whisper. You'll be able to explore most inference parameters or use the Notebook as-is to store the transcript and video audio in your Google Drive.

# %%
#@markdown # **Check GPU type** 🕵️

#@markdown The type of GPU you get assigned in your Colab session defined the speed at which the video will be transcribed.
#@markdown The higher the number of floating point operations per second (FLOPS), the faster the transcription.
#@markdown But even the least powerful GPU available in Colab is able to run any Whisper model.
#@markdown Make sure you've selected `GPU` as hardware accelerator for the Notebook (Runtime &rarr; Change runtime type &rarr; Hardware accelerator).

#@markdown |  GPU   |  GPU RAM   | FP32 teraFLOPS |     Availability   |
#@markdown |:------:|:----------:|:--------------:|:------------------:|
#@markdown |  T4    |    16 GB   |       8.1      |         Free       |
#@markdown | P100   |    16 GB   |      10.6      |      Colab Pro     |
#@markdown | V100   |    16 GB   |      15.7      |  Colab Pro (Rare)  |

#@markdown ---
#@markdown **Factory reset your Notebook's runtime if you want to get assigned a new GPU.**

# !nvidia-smi -L

# !nvidia-smi
# Out:
# GPU 0: NVIDIA A100-SXM4-40GB (UUID: GPU-b7d7d397-e4bb-832e-3983-84b0d21c4f42)
# Tue Apr 11 20:16:49 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    44W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#@markdown # **Install libraries** 🏗️
#@markdown This cell will take a little while to download several libraries, including Whisper.

#@markdown ---

! pip install git+https://github.com/openai/whisper.git
! pip install pytube

import sys
import warnings
import whisper
from pathlib import Path
import pytube
import subprocess
import torch
import shutil
import numpy as np
from IPython.display import display, Markdown, YouTubeVideo

device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-nisln51p
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-nisln51p
#   Resolved https://github.com/openai/whisper.git to commit 76c901ab8d4558992c44138479c4d69eb52fadcb
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (1.22.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (9.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (0.56.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (2.0.0+cu118)
# Collecting tiktoken==0.3.1
#   Downloading tiktoken-0.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (4.65.0)
# Collecting ffmpeg-python==0.2.0
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from ffmpeg-python==0.2.0->openai-whisper==20230314) (0.18.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.9/dist-packages (from tiktoken==0.3.1->openai-whisper==20230314) (2.27.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.9/dist-packages (from tiktoken==0.3.1->openai-whisper==20230314) (2022.10.31)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->openai-whisper==20230314) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->openai-whisper==20230314) (16.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->openai-whisper==20230314) (3.11.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba->openai-whisper==20230314) (67.6.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->openai-whisper==20230314) (0.39.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->openai-whisper==20230314) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch->openai-whisper==20230314) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch->openai-whisper==20230314) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch->openai-whisper==20230314) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper==20230314) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper==20230314) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper==20230314) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper==20230314) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch->openai-whisper==20230314) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch->openai-whisper==20230314) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=797968 sha256=09beb0644163f6dec13e4aec6cfb98aced7c059890e9bb065e62610370a216c6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z5flmr76/wheels/fe/03/29/e7919208d11b4ab32972cb448bb84a9a675d92cd52c9a48341
# Successfully built openai-whisper
# Installing collected packages: ffmpeg-python, tiktoken, openai-whisper
# Successfully installed ffmpeg-python-0.2.0 openai-whisper-20230314 tiktoken-0.3.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytube
#   Downloading pytube-12.1.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-12.1.3
# Using device: cuda:0

# %%
#@markdown # **Optional:** Save data in Google Drive 💾
#@markdown Enter a Google Drive path and run this cell if you want to store the results inside Google Drive.

# Uncomment to copy generated images to drive, faster than downloading directly from colab in my experience.
from google.colab import drive
drive_mount_path = Path("/") / "content" / "drive"
drive.mount(str(drive_mount_path))
drive_mount_path /= "My Drive"
#@markdown ---
drive_path = "Colab Notebooks/Whisper Youtube" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change your Google Drive path.**

drive_whisper_path = drive_mount_path / Path(drive_path.lstrip("/"))
drive_whisper_path.mkdir(parents=True, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
#@markdown # **Model selection** 🧠

#@markdown As of the first public release, there are 4 pre-trained options to play with:

#@markdown |  Size  | Parameters | English-only model | Multilingual model | Required VRAM | Relative speed |
#@markdown |:------:|:----------:|:------------------:|:------------------:|:-------------:|:--------------:|
#@markdown |  tiny  |    39 M    |     `tiny.en`      |       `tiny`       |     ~1 GB     |      ~32x      |
#@markdown |  base  |    74 M    |     `base.en`      |       `base`       |     ~1 GB     |      ~16x      |
#@markdown | small  |   244 M    |     `small.en`     |      `small`       |     ~2 GB     |      ~6x       |
#@markdown | medium |   769 M    |    `medium.en`     |      `medium`      |     ~5 GB     |      ~2x       |
#@markdown | large  |   1550 M   |        N/A         |      `large`       |    ~10 GB     |       1x       |

#@markdown ---
Model = 'medium' #@param ['tiny.en', 'tiny', 'base.en', 'base', 'small.en', 'small', 'medium.en', 'medium', 'large']
#@markdown ---
#@markdown **Run this cell again if you change the model.**

whisper_model = whisper.load_model(Model)

if Model in whisper.available_models():
    display(Markdown(
        f"**{Model} model is selected.**"
    ))
else:
    display(Markdown(
        f"**{Model} model is no longer available.**<br /> Please select one of the following:<br /> - {'<br /> - '.join(whisper.available_models())}"
    ))
# Out:
# **medium model is selected.**

# %%
#@markdown # **Video selection** 📺

#@markdown Enter the URL of the Youtube video you want to transcribe, wether you want to save the audio file in your Google Drive, and run the cell.

Type = "Youtube video or playlist" #@param ['Youtube video or playlist', 'Google Drive']
#@markdown ---
#@markdown #### **Youtube video or playlist**
URL = "https://www.youtube.com/watch?v=TCls75M7egE" #@param {type:"string"}
store_audio = True #@param {type:"boolean"}
#@markdown ---
#@markdown #### **Google Drive video, audio (mp4, wav), or folder containing video and/or audio files**
video_path = "Colab Notebooks/transcription/my_video.mp4" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change the video.**

video_path_local_list = []

if Type == "Youtube video or playlist":
    
    try:
        list_video_yt = [pytube.YouTube(URL)]
    except Exception:
        try:
            list_video_yt = list(pytube.Playlist(URL).videos)
        except Exception:
            raise(RuntimeError(f"{URL} isn't recgnized."))
    
    for video_yt in list_video_yt:
        try:
            video_yt.check_availability()
            display(
                YouTubeVideo(video_yt.video_id)
            )
        except pytube.exceptions.VideoUnavailable:
            display(
                Markdown(f"**{URL} isn't available.**"),
            )
            raise(RuntimeError(f"{URL} isn't available."))
        video_path_local = Path(".").resolve() / (video_yt.video_id+".mp4")
        video_yt.streams.filter(
            type="audio",
            mime_type="audio/mp4",
            abr="48kbps"
        ).first().download(
            output_path = video_path_local.parent,
            filename = video_path_local.name
        )
        if store_audio:
            shutil.copy(video_path_local, drive_whisper_path / video_path_local.name)
        video_path_local_list.append(video_path_local)

elif Type == "Google Drive":
    # video_path_drive = drive_mount_path / Path(video_path.lstrip("/"))
    video_path = drive_mount_path / Path(video_path.lstrip("/"))
    if video_path.is_dir():
        for video_path_drive in video_path.glob("**/*"):
            if video_path_drive.is_file():
                display(Markdown(f"**{str(video_path_drive)} selected for transcription.**"))
            elif video_path_drive.is_dir():
                display(Markdown(f"**Subfolders not supported.**"))
            else:
                display(Markdown(f"**{str(video_path_drive)} does not exist, skipping.**"))
            video_path_local = Path(".").resolve() / (video_path_drive.name)
            shutil.copy(video_path_drive, video_path_local)
            video_path_local_list.append(video_path_local)
    elif video_path.is_file():
        video_path_local = Path(".").resolve() / (video_path.name)
        shutil.copy(video_path, video_path_local)
        video_path_local_list.append(video_path_local)
        display(Markdown(f"**{str(video_path)} selected for transcription.**"))
    else:
        display(Markdown(f"**{str(video_path)} does not exist.**"))

else:
    raise(TypeError("Please select supported input type."))

for video_path_local in video_path_local_list:
    if video_path_local.suffix == ".mp4":
        video_path_local = video_path_local.with_suffix(".wav")
        result  = subprocess.run(["ffmpeg", "-i", str(video_path_local.with_suffix(".mp4")), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(video_path_local)])

# %%
#@markdown # **Run the model** 🚀

#@markdown Run this cell to execute the transcription of the video. This can take a while and very based on the length of the video and the number of parameters of the model selected above.

#@markdown ## **Parameters** ⚙️

#@markdown ### **Behavior control**
#@markdown ---
language = "Chinese" #@param ['Auto detection', 'Afrikaans', 'Albanian', 'Amharic', 'Arabic', 'Armenian', 'Assamese', 'Azerbaijani', 'Bashkir', 'Basque', 'Belarusian', 'Bengali', 'Bosnian', 'Breton', 'Bulgarian', 'Burmese', 'Castilian', 'Catalan', 'Chinese', 'Croatian', 'Czech', 'Danish', 'Dutch', 'English', 'Estonian', 'Faroese', 'Finnish', 'Flemish', 'French', 'Galician', 'Georgian', 'German', 'Greek', 'Gujarati', 'Haitian', 'Haitian Creole', 'Hausa', 'Hawaiian', 'Hebrew', 'Hindi', 'Hungarian', 'Icelandic', 'Indonesian', 'Italian', 'Japanese', 'Javanese', 'Kannada', 'Kazakh', 'Khmer', 'Korean', 'Lao', 'Latin', 'Latvian', 'Letzeburgesch', 'Lingala', 'Lithuanian', 'Luxembourgish', 'Macedonian', 'Malagasy', 'Malay', 'Malayalam', 'Maltese', 'Maori', 'Marathi', 'Moldavian', 'Moldovan', 'Mongolian', 'Myanmar', 'Nepali', 'Norwegian', 'Nynorsk', 'Occitan', 'Panjabi', 'Pashto', 'Persian', 'Polish', 'Portuguese', 'Punjabi', 'Pushto', 'Romanian', 'Russian', 'Sanskrit', 'Serbian', 'Shona', 'Sindhi', 'Sinhala', 'Sinhalese', 'Slovak', 'Slovenian', 'Somali', 'Spanish', 'Sundanese', 'Swahili', 'Swedish', 'Tagalog', 'Tajik', 'Tamil', 'Tatar', 'Telugu', 'Thai', 'Tibetan', 'Turkish', 'Turkmen', 'Ukrainian', 'Urdu', 'Uzbek', 'Valencian', 'Vietnamese', 'Welsh', 'Yiddish', 'Yoruba']
#@markdown > Language spoken in the audio, use `Auto detection` to let Whisper detect the language.
#@markdown ---
verbose = 'Live transcription' #@param ['Live transcription', 'Progress bar', 'None']
#@markdown > Whether to print out the progress and debug messages.
#@markdown ---
output_format = 'srt' #@param ['txt', 'vtt', 'srt', 'tsv', 'json', 'all']
#@markdown > Type of file to generate to record the transcription.
#@markdown ---
task = 'transcribe' #@param ['transcribe', 'translate']
#@markdown > Whether to perform X->X speech recognition (`transcribe`) or X->English translation (`translate`).
#@markdown ---

#@markdown <br/>

#@markdown ### **Optional: Fine tunning** 
#@markdown ---
temperature = 0.15 #@param {type:"slider", min:0, max:1, step:0.05}
#@markdown > Temperature to use for sampling.
#@markdown ---
temperature_increment_on_fallback = 0.2 #@param {type:"slider", min:0, max:1, step:0.05}
#@markdown > Temperature to increase when falling back when the decoding fails to meet either of the thresholds below.
#@markdown ---
best_of = 5 #@param {type:"integer"}
#@markdown > Number of candidates when sampling with non-zero temperature.
#@markdown ---
beam_size = 8 #@param {type:"integer"}
#@markdown > Number of beams in beam search, only applicable when temperature is zero.
#@markdown ---
patience = 1.0 #@param {type:"number"}
#@markdown > Optional patience value to use in beam decoding, as in [*Beam Decoding with Controlled Patience*](https://arxiv.org/abs/2204.05424), the default (1.0) is equivalent to conventional beam search.
#@markdown ---
length_penalty = -0.05 #@param {type:"slider", min:-0.05, max:1, step:0.05}
#@markdown > Optional token length penalty coefficient (alpha) as in [*Google's Neural Machine Translation System*](https://arxiv.org/abs/1609.08144), set to negative value to uses simple length normalization.
#@markdown ---
suppress_tokens = "-1" #@param {type:"string"}
#@markdown > Comma-separated list of token ids to suppress during sampling; '-1' will suppress most special characters except common punctuations.
#@markdown ---
initial_prompt = "" #@param {type:"string"}
#@markdown > Optional text to provide as a prompt for the first window.
#@markdown ---
condition_on_previous_text = True #@param {type:"boolean"}
#@markdown > if True, provide the previous output of the model as a prompt for the next window; disabling may make the text inconsistent across windows, but the model becomes less prone to getting stuck in a failure loop.
#@markdown ---
fp16 = True #@param {type:"boolean"}
#@markdown > whether to perform inference in fp16.
#@markdown ---
compression_ratio_threshold = 2.4 #@param {type:"number"}
#@markdown > If the gzip compression ratio is higher than this value, treat the decoding as failed.
#@markdown ---
logprob_threshold = -1.0 #@param {type:"number"}
#@markdown > If the average log probability is lower than this value, treat the decoding as failed.
#@markdown ---
no_speech_threshold = 0.6 #@param {type:"slider", min:-0.0, max:1, step:0.05}
#@markdown > If the probability of the <|nospeech|> token is higher than this value AND the decoding has failed due to `logprob_threshold`, consider the segment as silence.
#@markdown ---

verbose_lut = {
    'Live transcription': True,
    'Progress bar': False,
    'None': None
}

args = dict(
    language = (None if language == "Auto detection" else language),
    verbose = verbose_lut[verbose],
    task = task,
    temperature = temperature,
    temperature_increment_on_fallback = temperature_increment_on_fallback,
    best_of = best_of,
    beam_size = beam_size,
    patience=patience,
    length_penalty=(length_penalty if length_penalty>=0.0 else None),
    suppress_tokens=suppress_tokens,
    initial_prompt=(None if not initial_prompt else initial_prompt),
    condition_on_previous_text=condition_on_previous_text,
    fp16=fp16,
    compression_ratio_threshold=compression_ratio_threshold,
    logprob_threshold=logprob_threshold,
    no_speech_threshold=no_speech_threshold
)

temperature = args.pop("temperature")
temperature_increment_on_fallback = args.pop("temperature_increment_on_fallback")
if temperature_increment_on_fallback is not None:
    temperature = tuple(np.arange(temperature, 1.0 + 1e-6, temperature_increment_on_fallback))
else:
    temperature = [temperature]

if Model.endswith(".en") and args["language"] not in {"en", "English"}:
    warnings.warn(f"{Model} is an English-only model but receipted '{args['language']}'; using English instead.")
    args["language"] = "en"

for video_path_local in video_path_local_list:
    display(Markdown(f"### {video_path_local}"))

    video_transcription = whisper.transcribe(
        whisper_model,
        str(video_path_local),
        temperature=temperature,
        **args,
    )

    # Save output
    whisper.utils.get_writer(
        output_format=output_format,
        output_dir=video_path_local.parent
    )(
        video_transcription,
        str(video_path_local.stem),
        {
          "max_line_width": 47, 
          "max_line_count": 1,
          "highlight_words": False
        }
    )
    try:
        if output_format=="all":
            for ext in ('txt', 'vtt', 'srt', 'tsv', 'json'):
                transcript_file_name = video_path_local.stem + "." + ext
                shutil.copy(
                    video_path_local.parent / transcript_file_name,
                    drive_whisper_path / transcript_file_name
                )
                display(Markdown(f"**Transcript file created: {drive_whisper_path / transcript_file_name}**"))
        else:
            transcript_file_name = video_path_local.stem + "." + output_format
            shutil.copy(
                video_path_local.parent / transcript_file_name,
                drive_whisper_path / transcript_file_name
            )
            display(Markdown(f"**Transcript file created: {drive_whisper_path / transcript_file_name}**"))

    except:
        display(Markdown(f"**Transcript file created: {transcript_local_path}**"))
# Out:
# ### /content/TCls75M7egE.mp4
# [00:00.000 --> 00:06.000] Hello大家好,我相信很多朋友都看过这样一部美剧叫做西部世界
# [00:06.000 --> 00:10.000] 在西部世界里面呢,人们可以肆意的发泄自己的欲望
# [00:10.000 --> 00:15.000] 然后在这个公园的角落,其实有着很多很多的人工智能
# [00:15.000 --> 00:18.000] 他们这些人工智能足以一家乱真
# [00:18.000 --> 00:24.000] 通过这样一个科幻的方式,就不至于想要探讨人和科技的这个边界道理参谈
# [00:24.000 --> 00:26.000] 那么,随着最近AI的爆火
# [00:26.000 --> 00:30.000] 其实西部世界这样一个话题又回到了人们的眼中
# [00:30.000 --> 00:34.000] 那么,AI现在到底有多智能
# [00:34.000 --> 00:40.000] 它是否会像美剧西部世界里面描述的那样真的做到一家乱真呢
# [00:40.000 --> 00:44.000] 那我们今天就来探讨一下这样一个话题
# [00:44.000 --> 00:47.000] 欢迎大家收看我们今天新一期的视频
# [00:47.000 --> 00:52.000] 那么说起这个话题,最核心的原因还是由于这个人
# [00:52.000 --> 00:54.000] 他发了一条Twitter
# [00:54.000 --> 00:56.000] 这个人是什么人呢?
# [00:56.000 --> 00:58.000] 他现在就职于OpenAI
# [00:58.000 --> 01:01.000] 曾经是特斯拉AI部门的主管
# [01:01.000 --> 01:04.000] 叫做Andre Kapathy
# [01:04.000 --> 01:08.000] 然后他发的这个Twitter特别特别的有意思
# [01:08.000 --> 01:11.000] 其实就是讲的他们做了一个论文
# [01:11.000 --> 01:17.000] 这个论文核心的事情就是创造了25个AI的虚拟角色
# [01:17.000 --> 01:20.000] 然后放到了一个游戏之中
# [01:20.000 --> 01:27.000] 然后让这些AI的虚拟角色在这样的一个游戏空间中生活
# [01:27.000 --> 01:31.000] 这些AI角色和AI角色之间是可以进行互动和交流的
# [01:31.000 --> 01:34.000] 然后我们也可以通过进入到这个游戏去看
# [01:34.000 --> 01:36.000] 他们相互之间是怎么交流的
# [01:36.000 --> 01:42.000] 并且去让他们模拟出一个正常人的行为
# [01:42.000 --> 01:49.000] 其实这样的一个话题是我们能看到AI应用落地的一个非常直接的方向
# [01:49.000 --> 01:53.000] 因为现在随着最近塞尔达的预告片也出来了
# [01:53.000 --> 01:58.000] 大家都知道开放世界这样的游戏的潜力到底有多大
# [01:58.000 --> 02:03.000] 那么如果说我游戏里面的NPC都可以用人工智能去做
# [02:03.000 --> 02:06.000] 会让玩家更有真实感和铁感
# [02:06.000 --> 02:08.000] 有很多游戏公司都在做这样的工作
# [02:08.000 --> 02:10.000] 这是很直接的一个例子
# [02:10.000 --> 02:16.000] 大部分是斯坦福的人还有微软的人来做的这样一件事情
# [02:16.000 --> 02:18.000] 发了一篇这样的论文
# [02:18.000 --> 02:20.000] 然后做了一个这样的Demo
# [02:20.000 --> 02:24.000] 实现了这25个游戏内的角色
# [02:24.000 --> 02:27.000] 每个人都有着自己的不同的人设
# [02:27.000 --> 02:30.000] 然后每个人都可以跟对方进行交流
# [02:30.000 --> 02:34.000] 我们可以看到这其实是一个应用性的产品
# [02:34.000 --> 02:36.000] 然后是一篇应用性质的论文
# [02:36.000 --> 02:40.000] 但是呢它呈现的方式非常有意思
# [02:40.000 --> 02:42.000] 所以引起了很多人很大的兴趣
# [02:42.000 --> 02:45.000] 就是说这么有意思的一个东西
# [02:45.000 --> 02:46.000] 到底是怎么样做的
# [02:46.000 --> 02:48.000] 它到底解决了什么样的问题
# [02:48.000 --> 02:52.000] 那我今天根据这篇论文的结果我们来看一下
# [02:52.000 --> 02:55.000] 首先还是一样给大家看一下这个Demo
# [02:55.000 --> 02:57.000] 它到底是一个什么样的游戏呢
# [02:57.000 --> 03:00.000] 你如果去看你会看到这里面有很多很多的小人
# [03:00.000 --> 03:02.000] 他们之间是可以去对话的
# [03:02.000 --> 03:03.000] 然后还有一些房间
# [03:03.000 --> 03:06.000] 这些房间呢人们是可以进行休息的
# [03:06.000 --> 03:09.000] 还有这些别的一些地方
# [03:09.000 --> 03:11.000] 大家都是在做自己的事情
# [03:11.000 --> 03:12.000] 然后你如果往下翻呢
# [03:12.000 --> 03:15.000] 你就可以知道现在这个现在的时间
# [03:15.000 --> 03:17.000] 然后每个人在干什么
# [03:17.000 --> 03:18.000] 我们可以去看一看每个人在干什么
# [03:18.000 --> 03:20.000] 比如说这个是谁呀
# [03:20.000 --> 03:22.000] 这个是Adam Smith
# [03:22.000 --> 03:24.000] Current Action是Having Lunch
# [03:24.000 --> 03:25.000] Location是在这个地方
# [03:25.000 --> 03:27.000] 如果你想看他的Detail
# [03:27.000 --> 03:28.000] 你可以把这个Detail打开
# [03:30.000 --> 03:32.000] 你就可以看到这个人
# [03:32.000 --> 03:35.000] 他的这个人物的这个性格
# [03:35.000 --> 03:38.000] 是有一些这个现状
# [03:38.000 --> 03:40.000] 然后以及他的这个Daily Requirements
# [03:40.000 --> 03:42.000] 然后这些数据都是在这个地方
# [03:42.000 --> 03:44.000] 包括后面有他的日志和记录
# [03:45.000 --> 03:47.000] 这些都是非常有意思的一个点
# [03:47.000 --> 03:49.000] 那么回到这样的一个地方
# [03:49.000 --> 03:51.000] 就是你可以看到
# [03:51.000 --> 03:52.000] 在这样的一个小城镇里面
# [03:52.000 --> 03:55.000] 每个AI呢都会根据命令去做
# [03:55.000 --> 03:57.000] 他自己的事情
# [03:57.000 --> 03:59.000] 他也会能够跟别人打招呼
# [03:59.000 --> 04:02.000] 当然这个地方他的表现是有一定的随机性的
# [04:02.000 --> 04:06.000] 和我们那种比较死板的机器人是不太一样的
# [04:06.000 --> 04:08.000] 如果你玩过这个GTA是吧
# [04:08.000 --> 04:11.000] 里面的机器人都是比较陌生成归的
# [04:11.000 --> 04:14.000] 所以这个就是这样的一个游戏
# [04:14.000 --> 04:15.000] 他有趣的地方
# [04:15.000 --> 04:18.000] 你可以把他看成是一个小型的西部世界
# [04:18.000 --> 04:21.000] 这些人这些角色
# [04:21.000 --> 04:23.000] 从某种程度上来说是自主自发的
# [04:23.000 --> 04:26.000] 在进行活动和交流
# [04:26.000 --> 04:30.000] 当然我们要看他到底是多自主自发
# [04:30.000 --> 04:33.000] 还是要通过这个论文去看
# [04:33.000 --> 04:36.000] 并不是说他是一个完全自主自发的东西
# [04:38.000 --> 04:40.000] 那么回到这个论文本身
# [04:40.000 --> 04:44.000] 论文的这个introduction里面就非常直接的告诉我们
# [04:44.000 --> 04:49.000] 他这个论文最核心的一些创新点是在哪
# [04:49.000 --> 04:51.000] 他其实是把这个创新点分成了三个部分
# [04:51.000 --> 04:54.000] 然后最关键的你就看这句话就行了
# [04:54.000 --> 04:56.000] 首先第一个部分
# [04:56.000 --> 04:59.000] 他做了一个memory stream的这个系统
# [04:59.000 --> 05:02.000] 这个系统是用来存储这个人物的长期记忆的
# [05:02.000 --> 05:07.000] 也就是模拟人对长期记忆的这样的一个行为
# [05:07.000 --> 05:09.000] 第二个部分叫做reflection
# [05:09.000 --> 05:13.000] 这个reflection是第二个记忆系统
# [05:13.000 --> 05:19.000] 但是这个记忆系统是针对特定的推断去做的一个优化
# [05:19.000 --> 05:22.000] 就是当我这个人物角色想要去做一些判定
# [05:22.000 --> 05:24.000] 做些总结的时候
# [05:24.000 --> 05:26.000] 会根据我这第二个记忆系统去做
# [05:26.000 --> 05:28.000] 而不仅仅依赖于第一个系统
# [05:28.000 --> 05:30.000] 第三个叫做planning
# [05:30.000 --> 05:33.000] planning其实就是这个人他今天要做什么事情
# [05:34.000 --> 05:37.000] 然后他是在这个框架之内完成的
# [05:37.000 --> 05:40.000] 而不是完全跳脱于这个框架之外
# [05:40.000 --> 05:42.000] 然后去执行一些命令
# [05:42.000 --> 05:43.000] 所以你可以看到
# [05:43.000 --> 05:45.000] 他在这个论文里面
# [05:45.000 --> 05:49.000] 更多的做的是对于AI行为的一个优化
# [05:49.000 --> 05:55.000] 他行为优化的方向是尽量的去模拟人的一种思考方式
# [05:55.000 --> 05:57.000] 就比如说我给他说你应该有两个记忆系统
# [05:57.000 --> 05:59.000] 不同的记忆系统去负责不同的推断
# [05:59.000 --> 06:02.000] 然后你应该有一个规划的系统
# [06:02.000 --> 06:07.000] 你这个规划的系统是来保证你这个人物是尽量的像一个人
# [06:07.000 --> 06:09.000] 怎么样解释这些东西呢
# [06:09.000 --> 06:11.000] 我们其实往下翻就可以知道
# [06:11.000 --> 06:13.000] 他其实这个例子给的就是很多的
# [06:13.000 --> 06:16.000] 那在这个第四部分
# [06:16.000 --> 06:18.000] 他还对这个东西有一个详细的解释
# [06:18.000 --> 06:23.000] 他在这方面说了这个generative agent architecture
# [06:23.000 --> 06:25.000] 就是他创建的这样的一个人物
# [06:25.000 --> 06:27.000] 我是怎么样对他进行一个构造的
# [06:27.000 --> 06:30.000] 首先就是我们说的长期的一个记忆系统
# [06:31.000 --> 06:33.000] 这个地方他就分的也很清楚
# [06:33.000 --> 06:36.000] 就是我遇到的挑战是怎么我会怎么解决他的
# [06:36.000 --> 06:38.000] 这个记忆系统或者说长期的记忆系统
# [06:38.000 --> 06:39.000] 要解决的一个问题就是
# [06:39.000 --> 06:42.000] 怎么样让AI记住他原来发生过的一些事情
# [06:42.000 --> 06:44.000] 然后对这些事情做总结
# [06:44.000 --> 06:46.000] 然后还要对这些事情做衰减
# [06:46.000 --> 06:47.000] 就像人嘛
# [06:47.000 --> 06:48.000] 你看他虽然能记住东西
# [06:48.000 --> 06:50.000] 但是他也会忘东西
# [06:50.000 --> 06:53.000] 他大概是通过一些数学方式和
# [06:53.000 --> 06:54.000] ChartGPD
# [06:54.000 --> 06:57.000] 他用的这个背后的模型还是ChartGPD 3.5 Turbo
# [06:57.000 --> 07:01.000] 这样的一个东西来模拟了一个人是怎么样记东西的
# [07:01.000 --> 07:03.000] 第二部分叫做reflection
# [07:03.000 --> 07:05.000] 我也不知道该怎么样翻译
# [07:05.000 --> 07:08.000] 这地方要解决的一个问题是
# [07:08.000 --> 07:11.000] 很多时候我们不是通过这种单纯的
# [07:11.000 --> 07:17.000] 不经过处理的这个见到的事情去做的判断
# [07:17.000 --> 07:21.000] 很多时候我还是要去做一些特定情况下的推断
# [07:21.000 --> 07:23.000] 这方面举个很简单的例子
# [07:23.000 --> 07:25.000] 举个很简单的例子就是他说
# [07:25.000 --> 07:29.000] 如果说我让AI去选择他跟谁最亲近
# [07:29.000 --> 07:32.000] 如果他单纯的用一个维度去判断
# [07:32.000 --> 07:34.000] 比如说我判断我跟谁见面见的次数最多
# [07:34.000 --> 07:36.000] 我就跟谁最亲近的话
# [07:36.000 --> 07:39.000] 那所有的AI可能最亲近的人就只是他的邻居
# [07:39.000 --> 07:41.000] 因为他可能碰到自己的邻居碰到的最多
# [07:41.000 --> 07:43.000] 那么这方面我们就要引入另外一个变量
# [07:43.000 --> 07:44.000] 来告诉他
# [07:44.000 --> 07:46.000] 或者说来提升权重值说
# [07:46.000 --> 07:50.000] 你应该是跟另外一个人有更深度的交流
# [07:50.000 --> 07:52.000] 你才会跟他更多的亲近
# [07:52.000 --> 07:55.000] 所以这地方虽然是二层记忆的一个概念
# [07:55.000 --> 07:59.000] 但核心还是有点像通过这个Find Turing的方式
# [07:59.000 --> 08:02.000] 或者说是我给他设定了更多的Promote
# [08:02.000 --> 08:05.000] 更多的参数让他做出这样的一个推断
# [08:05.000 --> 08:08.000] 所以其实还是一个应用层面上的问题
# [08:08.000 --> 08:11.000] 具体他怎么解决大家可以来看一下这个论文
# [08:12.000 --> 08:14.000] 第三个部分叫做计划
# [08:14.000 --> 08:18.000] 这个要解决的问题就是他要像人
# [08:18.000 --> 08:21.000] 那他应该和人这种常识性的行为是一致的
# [08:21.000 --> 08:24.000] 比如说一个人一天只吃三顿饭
# [08:24.000 --> 08:27.000] 那我给每个角色我都还是需要有一个限制
# [08:27.000 --> 08:29.000] 就是你今天只能吃三顿饭
# [08:29.000 --> 08:32.000] 因为如果我不告诉他你今天只能吃三顿饭
# [08:32.000 --> 08:34.000] 他没有一个Planning的系统在这个地方的话
# [08:34.000 --> 08:37.000] 那他可能他接受的消息是
# [08:37.000 --> 08:38.000] 我12点钟就要吃饭
# [08:38.000 --> 08:40.000] 或者说我中午要吃饭
# [08:40.000 --> 08:41.000] 结果他12点吃了一次
# [08:41.000 --> 08:43.000] 12点万吃了一次
# [08:43.000 --> 08:44.000] 1点钟吃了一次
# [08:44.000 --> 08:45.000] 因为这都是中午
# [08:45.000 --> 08:47.000] 他并没有有这样的一个意识
# [08:47.000 --> 08:49.000] 我是中午只能吃一顿饭
# [08:49.000 --> 08:52.000] 或者说我一天只能吃三顿饭这样的一个概念
# [08:52.000 --> 08:55.000] 所以在规范这个AI的行为的时候
# [08:55.000 --> 08:57.000] 给他引入了一个Planning的概念
# [08:57.000 --> 08:58.000] 在这个地方
# [08:58.000 --> 09:00.000] 然后这个Planning就是一条一条一条
# [09:00.000 --> 09:02.000] 你这个人今天做什么样的事情
# [09:02.000 --> 09:03.000] 做什么样的事情
# [09:04.000 --> 09:09.000] 那这三个去让AI这个Agent
# [09:09.000 --> 09:11.000] 看起来更像人的方式
# [09:11.000 --> 09:14.000] 是这篇论文里面用到的主要的一个架构
# [09:14.000 --> 09:15.000] 或者说主要的一个方式
# [09:15.000 --> 09:17.000] 这样的一个方式
# [09:17.000 --> 09:18.000] 所有的Log
# [09:18.000 --> 09:21.000] 所有他我们刚提到的记忆系统也好
# [09:21.000 --> 09:22.000] Planning的系统也好
# [09:22.000 --> 09:25.000] 其实在这个State Details里
# [09:25.000 --> 09:26.000] 你其实都是能看见的
# [09:28.000 --> 09:30.000] 我们如果往下翻你可以看到
# [09:30.000 --> 09:32.000] 这还有个Daily requirement
# [09:32.000 --> 09:33.000] 他这天要做什么
# [09:33.000 --> 09:35.000] 也就是他的这个Planning的系统
# [09:35.000 --> 09:38.000] 然后在后面就是他的记忆
# [09:38.000 --> 09:39.000] 他的Memory
# [09:39.000 --> 09:40.000] 他到底发生了什么
# [09:41.000 --> 09:43.000] 然后通过这样的一些事情
# [09:43.000 --> 09:46.000] 能够让这个AI看起来更像一个人
# [09:47.000 --> 09:49.000] 这个是最核心最核心的一个点
# [09:49.000 --> 09:52.000] 当然这个论文里面也提了很多的
# [09:52.000 --> 09:54.000] 他们怎么样去做React
# [09:54.000 --> 09:57.000] 你看他有做Diagram的方式
# [09:57.000 --> 10:01.000] 然后还有一些这个具体的Evaluation
# [10:01.000 --> 10:04.000] 包括现在他们虽然人和人之间
# [10:04.000 --> 10:07.000] 或者说这个AI和AI之间能够交流
# [10:07.000 --> 10:09.000] 但是他交流的信息
# [10:09.000 --> 10:10.000] 真的是有用的信息吗
# [10:10.000 --> 10:12.000] 还是两个AI完全在胡说八道
# [10:12.000 --> 10:15.000] 这东西可能没有人能够知道
# [10:16.000 --> 10:20.000] 所以你可以看到他在这个Evaluation的地方
# [10:20.000 --> 10:25.000] 他还需要有人能够帮他去做人工的判断
# [10:25.000 --> 10:27.000] 他还在这个论文里面招人
# [10:30.000 --> 10:33.000] 他还在这个他这个论文里面提到
# [10:33.000 --> 10:36.000] 有人工的判断是帮助他们去做Evaluation
# [10:36.000 --> 10:38.000] 是好还是坏的这样的一个方式
# [10:39.000 --> 10:41.000] 所以我们可以看到他这篇论文
# [10:41.000 --> 10:43.000] 实现的最核心的一个点
# [10:43.000 --> 10:46.000] 并不是让AI往外更多的发散
# [10:46.000 --> 10:50.000] 更像是让AI通过一些限制的方式
# [10:50.000 --> 10:56.000] 看起来更像一个人们认知内的一个人类的行为
# [10:56.000 --> 10:58.000] 也就是我不是往外扩
# [10:58.000 --> 11:00.000] 我其实是往里收的
# [11:00.000 --> 11:02.000] 然后在应用层面上
# [11:02.000 --> 11:04.000] 让人们或者是在游戏中能够看到
# [11:04.000 --> 11:06.000] 哦有这样的一个东西啊
# [11:06.000 --> 11:07.000] 它可以解决这样的一个问题
# [11:07.000 --> 11:09.000] 从而提高真实感
# [11:09.000 --> 11:14.000] 核心还是提高人的体验和提高这个游戏的这个真实感
# [11:14.000 --> 11:19.000] 所以他有一些些西部世界的苗头
# [11:19.000 --> 11:23.000] 至少从学术上来说给我们提供了一个demo
# [11:23.000 --> 11:25.000] 给我们提供了一个方法
# [11:25.000 --> 11:31.000] 能够让我们通过一些AI和模型之间的这种建立
# [11:31.000 --> 11:32.000] 来模拟人
# [11:32.000 --> 11:34.000] 来让他看起来更像一个人
# [11:34.000 --> 11:36.000] 但是他我不觉得他一定会替代人
# [11:36.000 --> 11:38.000] 但是他至少现在看起来越来越像一个人了
# [11:38.000 --> 11:40.000] 这个里面三种方法
# [11:40.000 --> 11:42.000] 一个记忆
# [11:42.000 --> 11:43.000] 一个reflection
# [11:43.000 --> 11:44.000] 一个planning
# [11:44.000 --> 11:48.000] 其实还是从这种promote的角度去给他加的
# [11:48.000 --> 11:50.000] 那如果你想要让他更像人的话
# [11:50.000 --> 11:53.000] 你可能是需要在这个过程中再去发现
# [11:53.000 --> 11:56.000] 他有哪些地方是明显能够让我觉得很出戏的
# [11:56.000 --> 11:59.000] 那我通过一些方式再去不断的去修正他
# [11:59.000 --> 12:02.000] 再不断的其实从某种程度来说
# [12:02.000 --> 12:04.000] 也是做的一个fine-tuning的过程
# [12:04.000 --> 12:05.000] 微调的一个过程
# [12:05.000 --> 12:07.000] 所以我们可以看到
# [12:07.000 --> 12:11.000] 应用类的AI已经有能够落地的场景了
# [12:11.000 --> 12:15.000] 并且能够在真实感这种情
# [12:15.000 --> 12:19.000] 并且能够不断的在优化用户的这个体验
# [12:19.000 --> 12:24.000] 能够让人们从技术的进步里面获得一些益处
# [12:24.000 --> 12:27.000] 当然从反面来说也会有一个恐怖谷效应
# [12:27.000 --> 12:29.000] 也就是当AI越来越像人
# [12:29.000 --> 12:30.000] 到达一个零介质的时候
# [12:30.000 --> 12:32.000] 人们会觉得他有点恐怖
# [12:32.000 --> 12:34.000] 不过我个人看到这样的技术
# [12:34.000 --> 12:35.000] 我还是觉得挺兴奋的
# [12:35.000 --> 12:38.000] 就是前两天还觉得会不会
# [12:38.000 --> 12:40.000] 有游戏用这样的一个技术
# [12:40.000 --> 12:41.000] 现在就看到这样的一个demo
# [12:41.000 --> 12:43.000] 有人在研究这样一件事情
# [12:43.000 --> 12:45.000] 未来游戏会越来越好玩
# [12:45.000 --> 12:46.000] 是吧
# [12:46.000 --> 12:48.000] 所以我还是挺兴奋的
# [12:48.000 --> 12:50.000] 那今天的节目主要内容就是这些
# [12:50.000 --> 12:52.000] 如果你有不懂的或者想讨论东西呢
# [12:52.000 --> 12:53.000] 欢迎在我们的视频下方留言
# [12:53.000 --> 12:54.000] 或者加入我们的discord社群
# [12:54.000 --> 12:55.000] 跟大家进行一个讨论
# [12:55.000 --> 12:58.000] 我以上所说的东西都不构成投资建议
# [12:58.000 --> 12:59.000] 大家做好自己的调研
# [12:59.000 --> 13:00.000] 如果你喜欢我们的视频的话
# [13:00.000 --> 13:01.000] 欢迎点赞收藏
# [13:01.000 --> 13:03.000] 转发订阅评论我们的频道
# [13:03.000 --> 13:04.000] 这对我们来说非常重要
# [13:04.000 --> 13:05.000] 感谢你的收看
# [13:05.000 --> 13:06.000] 祝你学习顺利
# **Transcript file created: /content/drive/My Drive/Colab Notebooks/Whisper Youtube/TCls75M7egE.srt**
